# %% [markdown]
# ## Plotting with MatPlotLib and Seaborn

# %%
# Source: Prof. Levy's lecture from last Spring!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Subplots

# %%
x = range(300)
def gen_ys(obs):
    y = np.random.choice([-1, 0, 1], obs)
    return np.cumsum(y) # random walk
ys = [gen_ys(300) for _ in range(4)]
ys
# Out:
# [array([ -1,  -2,  -3,  -4,  -5,  -5,  -6,  -6,  -5,  -5,  -5,  -5,  -4,
#          -5,  -6,  -7,  -8,  -8,  -8,  -9, -10, -11, -10, -10,  -9, -10,
#          -9, -10,  -9,  -8,  -8,  -7,  -8,  -7,  -7,  -7,  -7,  -8,  -8,
#          -9, -10, -10, -11, -10, -10,  -9, -10,  -9,  -8,  -7,  -6,  -5,
#          -5,  -6,  -7,  -7,  -6,  -5,  -5,  -6,  -7,  -7,  -8,  -7,  -8,
#          -9,  -8,  -9,  -9, -10, -10, -11, -11, -10,  -9,  -8,  -8,  -9,
#         -10, -10, -11, -12, -11, -10,  -9,  -8,  -8,  -9,  -9,  -8,  -8,
#          -9,  -9,  -9, -10,  -9, -10, -11, -10, -11, -10,  -9,  -8,  -9,
#         -10, -11, -12, -13, -14, -15, -16, -15, -15, -15, -14, -13, -14,
#         -13, -13, -14, -15, -15, -15, -14, -14, -13, -12, -11, -11, -12,
#         -11, -12, -11, -11, -11, -11, -12, -13, -14, -14, -14, -14, -15,
#         -15, -16, -15, -16, -17, -16, -16, -17, -16, -16, -15, -15, -15,
#         -16, -16, -15, -15, -16, -16, -15, -14, -13, -12, -12, -12, -11,
# ...

# %%
fig, ax = plt.subplots(2, 2)
ax
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026720FC0A48>,
# ...
#       dtype=object)

# %%
fig, ax = plt.subplots(2, 2)
flat_axis_list = [s for r in ax for s in r]
for s, y in zip(flat_axis_list, ys):
    s.plot(x, y)

# %% [markdown]
# ### Scatterplot

# %%
x = range(300)
y = gen_ys(300)
fig, ax = plt.subplots()
ax.plot(x, y, linestyle='', marker='.', markersize=1)
# ax.scatter(x,y)

# %% [markdown]
# ### Barplot

# %%
# Source: https://www.geeksforgeeks.org/bar-plot-in-matplotlib/
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())
  
# fig = plt.figure(figsize = (10, 5))

fig, ax = plt.subplots(figsize=(10,5))

# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %% [markdown]
# ### Customizing quality

# %%
fig, ax = plt.subplots()
color_palette_list = ['#009ACD', '#ADD8E6', '#63D1F4', '#0EBFE9',   
                      '#C1F0F6', '#0099CC']
labels = ['Creating Jobs', 'Cutting govt spending/reducing debt', 'Protecting Medicare/SS','Public Schools', 'Affordable healthcare', 'Other']
percentages = [29, 25,19,11,7, 9]
explode=(0.2,0.1, 0, 0, 0, 0)
ax.pie(percentages, explode=explode, labels=labels,  
       colors=color_palette_list[0:6], autopct='%1.0f%%', 
       shadow=False, startangle=0,   
       pctdistance=1.2,labeldistance=1.4);

# %% [markdown]
# ### Seaborn to the rescue!
# ### https://seaborn.pydata.org/

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x='total_bill', y='tip', data=tips)

# %%
sns.scatterplot(x='total_bill', y='tip', hue='smoker', data=tips);
