# %% [markdown]
# ## Data is here!
# ### Documentation is key!

# %% [markdown]
# ## Brief digression:
# 1. Good, clear variable naming (ex. if you have a list of movies, call it movies instead of something nondescript like my_list)
#
# 2. Good naming conventions (ex. naming classes like MyClass and functions like my_func)
#
# 3. Avoiding scattered import statements (these should all be at the top of your script)
#
# 4. Having the appropriate amount of comments (your code should be mostly readable on its own)
#
# 5. Making consistent style choices throughout your script (ex. not switching between single quotes and double quotes)

# %% [markdown]
# ## Importing files

# %%
import os
import pandas as pd
import numpy as np

# %%
in_path = r'C:\Users\kulkr\Downloads'
landfills = os.path.join(in_path, 'Solid_Waste_Landfill_Facilities.csv')
landfills
df_landfills = pd.read_csv(landfills)

# %% [markdown]
# ## Exploring the data

# %%
# df_landfills.head()
# df_landfills.tail()
df_landfills.describe()
# Out:
#                   X             Y     OBJECTID           SWID    COUNTYFIPS  \
# count  7.376000e+03  7.376000e+03  7376.000000    7376.000000   7375.000000
# mean  -1.028318e+07  4.704364e+06  3688.500000  277827.393845  27143.590644
# std    2.150844e+06  8.718842e+05  2129.412125  229645.794766  16626.578585
# min   -1.895026e+07  1.494466e+06     1.000000      21.000000   1001.000000
# 25%   -1.184592e+07  4.059407e+06  1844.750000   12768.750000  12033.000000
# 50%   -9.783578e+06  4.767693e+06  3688.500000  291454.500000  27015.000000
# 75%   -8.597688e+06  5.264688e+06  5532.250000  422159.250000  40023.000000
# max    1.938554e+07  1.149818e+07  7376.000000  783110.000000  78030.000000
#
#           LATITUDE    LONGITUDE     NAICS_CODE
# count  7376.000000  7376.000000    7376.000000
# mean     38.621983   -92.375341  562153.202007
# std       5.906610    19.321362      49.816963
# min      13.303838  -170.233066  562111.000000
# ...

# %%
df_landfills.head(2)
# Out:
#               X             Y  OBJECTID   SWID  \
# 0 -1.755830e+07  2.445467e+06         1  15744
# 1 -1.760235e+07  2.433461e+06         2  15750
#
#                                  NAME                          ADDRESS  \
# 0  KANEOHE MARINE CORPS BASE LANDFILL                MIDDAUGH ST, OAHU
# 1   WAIMANALO GULCH SANITARY LANDFILL  92-460 FARRINGTON HIGHWAY, OAHU
#
#       CITY STATE    ZIP           ZIP4  ...  \
# 0  KANEOHE    HI  96734  NOT AVAILABLE  ...
# 1  WAIANAE    HI  96707  NOT AVAILABLE  ...
#
#                                               SOURCE           SOURCEDATE  \
# 0  http://health.hawaii.gov/shwb/files/2013/06/oa...  2019/04/30 00:00:00
# 1  http://health.hawaii.gov/shwb/files/2013/06/oa...  2019/04/30 00:00:00
#
#   VAL_METHOD             VAL_DATE  \
# 0    IMAGERY  2020/01/15 00:00:00
# 1    IMAGERY  2020/01/15 00:00:00
#
#                                              WEBSITE        REG_ID  \
# ...

# %%
df_landfills.loc[2:]
# Out:
#                  X             Y  OBJECTID    SWID  \
# 2    -1.735269e+07  2.260402e+06         3   15751
# 3    -1.741299e+07  2.375050e+06         4   15740
# 4    -1.644167e+07  9.556203e+06         5     216
# 5    -1.362130e+07  4.926745e+06         6    6260
# 6    -1.361371e+07  4.894813e+06         7    6366
# ...            ...           ...       ...     ...
# 7371 -9.349944e+06  4.089620e+06      7372  783106
# 7372 -9.045854e+06  3.812496e+06      7373  783107
# 7373 -9.383050e+06  3.948313e+06      7374  783108
# 7374 -9.390744e+06  3.986422e+06      7375  783109
# 7375 -9.344830e+06  4.036984e+06      7376  783110
#
#                                                    NAME  \
# 2                    WEST HAWAII LANDFILL / PUU ANAHULU
# 3       CENTRAL MAUI LANDFILL REFUSE & RECYCLING CENTER
# 4     FAIRBANKS NORTH STAR BOROUGH LANDFILL (SOUTH C...
# 5                               ANDERSON LANDFILL, INC.
# 6                      TEHAMA COUNTY/RED BLUFF LANDFILL
# ...

# %%
# df_landfills['STATE'].unique()
len(df_landfills['STATE'].unique())
# Out:
# 53

# %% [markdown]
# ## Data manipulation

# %% [markdown]
# ### renaming

# %%
# df_landfills = df_landfills.rename(columns={'CITY': 'city'})

# df_landfills.rename(columns={'city': 'test'},inplace=True)

df_landfills.rename(str.lower, axis=1)
# Out:
#                  x             y  objectid    swid  \
# 0    -1.755830e+07  2.445467e+06         1   15744
# 1    -1.760235e+07  2.433461e+06         2   15750
# 2    -1.735269e+07  2.260402e+06         3   15751
# 3    -1.741299e+07  2.375050e+06         4   15740
# 4    -1.644167e+07  9.556203e+06         5     216
# ...            ...           ...       ...     ...
# 7371 -9.349944e+06  4.089620e+06      7372  783106
# 7372 -9.045854e+06  3.812496e+06      7373  783107
# 7373 -9.383050e+06  3.948313e+06      7374  783108
# 7374 -9.390744e+06  3.986422e+06      7375  783109
# 7375 -9.344830e+06  4.036984e+06      7376  783110
#
#                                                    name  \
# 0                    KANEOHE MARINE CORPS BASE LANDFILL
# 1                     WAIMANALO GULCH SANITARY LANDFILL
# 2                    WEST HAWAII LANDFILL / PUU ANAHULU
# 3       CENTRAL MAUI LANDFILL REFUSE & RECYCLING CENTER
# 4     FAIRBANKS NORTH STAR BOROUGH LANDFILL (SOUTH C...
# ...

# %% [markdown]
# ### subsetting

# %%
# df_landfills[df_landfills['STATE']=='IL']
df_landfills.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'SWID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'COUNTY', 'COUNTYFIPS',
#        'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE', 'NAICS_DESC',
#        'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'REG_ID',
#        'STATUSDATE', 'OWNER', 'CLOSE_DATE', 'PERMIT_NO'],
#       dtype='object')

# %%
# df_landfills[['NAME', 'ADDRESS', 'city']]
# df_landfill['NAME']

df_landfills[df_landfills['STATE']=='IL'][[name for name in df_landfills.columns if name.startswith('S')]]
# Out:
#        SWID STATE  STATUS                                             SOURCE  \
# 115   17898    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 116   17912    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 117   17883    IL  CLOSED  http://www.epa.illinois.gov/topics/waste-manag...
# 118   17919    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 120   17922    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 121   17879    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 122   17902    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 123   17914    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 124   17910    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 126   17904    IL    OPEN  https://www2.illinois.gov/epa/topics/waste-man...
# 127   17886    IL  CLOSED  http://www.epa.illinois.gov/topics/waste-manag...
# ...

# %% [markdown]
# ### Mapping

# %%
# https://www.geeksforgeeks.org/python-map-function/
def addition(n):
    return n + n
  
# We double all numbers using map()
numbers = (1, 2, 3, 4)
result = map(addition, numbers)
print(list(result))
# Out:
# [2, 4, 6, 8]

# %%
def add_usa(state):
    return ''.join([state, ', USA'])

                 
df_landfills['STATE'] = df_landfills['STATE'].map(add_usa)
df_landfills.head()
# Out:
#               X             Y  OBJECTID   SWID  \
# 0 -1.755830e+07  2.445467e+06         1  15744
# 1 -1.760235e+07  2.433461e+06         2  15750
# 2 -1.735269e+07  2.260402e+06         3  15751
# 3 -1.741299e+07  2.375050e+06         4  15740
# 4 -1.644167e+07  9.556203e+06         5    216
#
#                                                 NAME  \
# 0                 KANEOHE MARINE CORPS BASE LANDFILL
# 1                  WAIMANALO GULCH SANITARY LANDFILL
# 2                 WEST HAWAII LANDFILL / PUU ANAHULU
# 3    CENTRAL MAUI LANDFILL REFUSE & RECYCLING CENTER
# 4  FAIRBANKS NORTH STAR BOROUGH LANDFILL (SOUTH C...
#
#                            ADDRESS       city    STATE    ZIP           ZIP4  \
# 0                MIDDAUGH ST, OAHU    KANEOHE  HI, USA  96734  NOT AVAILABLE
# 1  92-460 FARRINGTON HIGHWAY, OAHU    WAIANAE  HI, USA  96707  NOT AVAILABLE
# 2       71-111 QUEEN KAAHUMANU HWY   WAIKOLOA  HI, USA  85034  NOT AVAILABLE
# ...

# %%
'hello'.join('world')
# Out:
# 'whelloohellorhellolhellod'

# %% [markdown]
# ### apply, applymap

# %%
# Source: https://www.geeksforgeeks.org/difference-between-map-applymap-and-apply-methods-in-pandas/
